# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
for i in range(100):
    A = np.random.randn(40,40)
    eigenval = np.linalg.eig(A)[0]
    plt.plot(np.real(eigenval),np.imag(eigenval), 's', markersize=1)

plt.axis('square')
plt.show()
