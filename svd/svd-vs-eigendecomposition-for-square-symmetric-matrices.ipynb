# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
A = np.random.rand(5,5)
A = A.T@A

W, L = np.linalg.eig(A)

U, S, V = np.linalg.svd(A)

plt.imshow(L)
plt.title('Eigenvectors')
plt.show()
plt.imshow(U)
plt.title('U')
plt.show()
plt.imshow(V)
plt.title('V')
plt.show()
